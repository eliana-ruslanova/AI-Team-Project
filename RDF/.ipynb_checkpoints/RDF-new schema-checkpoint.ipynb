# %%
import pandas as pd #for handling csv and csv contents
from rdflib import Graph, Literal, RDF, URIRef, Namespace #basic RDF handling
from rdflib.namespace import FOAF , XSD, RDFS, DCTERMS #most common namespaces
import urllib.parse #for parsing strings to URI's
import numpy as np
from array import array

# %% [markdown]
# Define Namespaces for the Data

# %%
g = Graph()
title = Namespace('http://example.org/title/')
author = Namespace('http://example.org/author/')
year = Namespace('http://example.org/year/')
doi = Namespace('http://example.org/doi/')
pmid = Namespace('http://example.org/PMID/')
journal = Namespace('http://example.org/journal/')
volume = Namespace('http://example.org/volume/')
abstract = Namespace('http://example.org/abstract/')
keyword_abstract = Namespace('http://example.org/keyword_abstract/')
keyword_mesh = Namespace('http://example.org/keywords_mesh/')
keyword_merged = Namespace('http://example.org/keywords_merged/')
links = Namespace('http://example.org/fulltext_links/')
articles = Namespace('http://example.org/related_articles/')
fields = Namespace('http://example.org/fields/')
subfields = Namespace('http://example.org/subfield/')
aimethod = Namespace('http://example.org/ai_method')

# %% [markdown]
# Upload the data files and merge new examples with diseases

# %%
new_example = pd.read_json('example_new.json')
diseases = pd.read_csv('mesh_papers_with_disease_n_abbr.csv')
diseases['PMID']= diseases['PMID'].replace('PMID:', '',regex=True)
new_example=new_example.merge(diseases, on='PMID', how='right')

# %%
algorithms = pd.read_csv("Book.csv", sep=';', header=0 )
algorithms.head(30)

# %%
regression = algorithms['regression'].values
instance_based = algorithms['instance based'].values
#regularization = algorithms['regularization'].values
decision_tree = algorithms['decision tree'].values
bayesian = algorithms['bayesian'].values
clustering = algorithms['clustering'].values
association_rule = algorithms['association rule learning'].values
ann = algorithms['artificial neural network'].values
deep_learning = algorithms['deepl learning'].values
dimensionality_reduction = algorithms['dimensionality reduction'].values
ensemble_algorithm = algorithms['ensemble algorithm'].values
regularization = ['Ridge Regression','Least Absolute Shrinkage and Selection Operator','Elastic Net','Least-Angle Regression','LASSO','LARS']

# %% [markdown]
# Start building the RDF Schema

# %%
for index, row in df.iterrows():
    
    authors = str(row['Authors']).split(";")
    for a in authors[:-1]:
        g.add((URIRef(pmid+str(row['PMID'])), DCTERMS['creator'], Literal(a, datatype=XSD.string) ))
        
    keywords = str(row['Keywords_Merged']).split(";")
    for key in keywords:
        g.add((URIRef(pmid+str(row['PMID'])), URIRef(keyword_merged+'key_merged'), Literal(key, datatype=XSD.string) ))
    
    fullTexts = str(row['FullTextLinks']).split(";")
    for text in fullTexts:
        g.add((URIRef(pmid+str(row['PMID'])), RDFS.comment, Literal(text, datatype=XSD.string) ))
        
    related = str(row['FullTextLinks']).split(";")
    for a in related:
        g.add((URIRef(pmid+str(row['PMID'])), RDFS.seeAlso, Literal(a, datatype=XSD.string) ))
    
    g.add((URIRef(pmid+str(row['PMID'])),RDF.type, Literal(row['PMID'])))
    g.add((URIRef(pmid+str(row['PMID'])), DCTERMS['identifier'], Literal(row['PMID']))) 
    g.add((URIRef(doi+str(row['PMID'])), DCTERMS['identifier'],Literal(row['Doi'], datatype=XSD.integer) ))
    g.add((URIRef(pmid+str(row['PMID'])), DCTERMS['publisher'], Literal(row['Journal'], datatype=XSD.string) ))
    #g.add((URIRef(pmid+str(row['PMID'])), URIRef(volume+'volume'), Literal(row['Volume'], datatype=XSD.string) ))
    g.add((URIRef(pmid+str(row['PMID'])), DCTERMS['abstract'], Literal(row['Abstract'], datatype=XSD.string) ))
    #g.add((URIRef(pmid+row['PMID']), URIRef(field+'field'), Literal(row['Field'], datatype=XSD.string) ))
    #g.add((URIRef(pmid+row['PMID']), RDFS.subclassOf, Literal(row['Subfield'], datatype=XSD.string) ))
    #g.add((URIRef(pmid+str(row['PMID'])), URIRef(aimethod), Literal(row['Methods'])))
    #g.add((URIRef(loc+urllib.parse.quote(row['Address'])), URIRef(schema+'name'), Literal(row['Address'], datatype=XSD.string) ))
    methods = str(row['Methods']).split('/')
    g.add((URIRef(pmid+str(row['PMID'])), )
    for x in methods:
        if x in regression :
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod))) 
        elif x in instance_based :
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in regularization :
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in decision_tree:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in bayesian:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in clustering:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in association_rule:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in ann:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in deep_learning:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in dimensionality_reduction:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        elif x in ensemble_algorithm:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))
        else:
            g.add((URIRef(pmid+str(row['PMID'])), RDFS.subClassOf, Literal(aimethod)))

   
    
    ##add the rdf for diseases

# %%
print(g.serialize(format='turtle').decode('UTF-8'))

# %% [markdown]
# Querying RDF via SPARQL

# %%
q = "select ?title ?abstract where {?title ?abstract <http://example.org/PMID/24694170>}"
x = g.query(q)
t = list(x)
print("----------------------------------------------------------------------------------------------")
for y in range(0,len(t)):
    ss=t[y][0]
    #search for id
    q = "select ?relation ?part  where {<"+ss+"> ?relation ?part}"
    xx = g.query(q)
    print(xx)

# %%
# <id, attribute, value>
#search PMID in the searh bar, and return the data with this PMID, and show its attribute and value, for example below PMID=31946810，and have 12 attributes and values
#<a,?,?>
q = "select ?attribute ?value where {<http://example.org/PMID/31946810>?attribute ?value}"
x = g.query(q)
t = list(x)
print(len(t))  
  
for i in t:
    print(i)
    print("----------------------------------------------------------------------------------------------")

# %%
# <id, attribute, value>
#search relationship/attribute title in the searh bar, you can change the other attribute
#we can see all the dataset is 79 data which have title
# <?,b,?>
q = "select ?id ?value where {?id <http://example.org/title/title> ?value}"  
x = g.query(q)
t = list(x)
print(len(t))

for i in t:
    print(i)
    print("----------------------------------------------------------------------------------------------")

# %%
# search value of title in the search bar, for example, search title value is 29993442, but can only do the exactly search
# <id, attribute, value>
# <?,?,c>
q = "select * where {?id <http://example.org/title/title> 29993442 }"  
x = g.query(q)
t = list(x)
print(len(t))   # only one data match this title value
print(t[0])

for i in range(0,len(t)):
    value = str(t[i]).replace("(rdflib.term.URIRef('","").replace("'),)","")  #extract the PMID URI, and then from PMID get all the data
    print(value)
    q = "select * where {<"+ value +"> ?attribute ?value}"  
    x = g.query(q)
    b = list(x)
    if (len(b) > 0) :
        for y in range(0,len(b)):
            print(str(b[y]))
            print("new attibute-------------------------------------------------------------")
        print("\n")
        print("new data-------------------------------------------")

# %%
pip install sparqlwrapper

# %%
from SPARQLWrapper import SPARQLWrapper
# maybe something can use in this package, but I don't use this below

# %%
# Above we can only do the exactly search, which can only get all the matched data with the exact vaule we know
#but we can not do the fuzzy query, and below try the fuzzy query
#when search 31 in the search bar, what will happen?
# <id, attribute, value>
q = "select ?id where {?id ?attribute ?value filter regex(?value, '31')}"
x = g.query(q)
t = list(x)
for i in range(0,len(t)):
    value = str(t[i]).replace("(rdflib.term.URIRef('","").replace("'),)","")
    q = "select * where {<"+ value +"> ?attribute ?value}"          # also get the PMID first and then get all the matched data
    x = g.query(q)
    b = list(x)
    if (len(b) > 0) :
        for y in range(0,len(b)):
            print(str(b[y]))
            print("new attibute-------------------------------------------------------------")
        print("\n")
        print("new data-------------------------------------------")

#we can see that as long as "31" appeare in the value, no matter what attibute, it will match.
#but when I want to search for the exact attibute 'title' which may have something like "**31**", I failed, I can only do with all attibutes.

# %%
# and maybe you can change the title to other attibutes and also try the fuzzy query.

# %%
indentation = []
indentation.append(0)
depth = 0

f = open("acm_hierarchy_restructure.txt", 'r')

for line in f:
    line = line[:-1]

    content = line.strip()
    indent = len(line) - len(content)
    if indent > indentation[-1]:
        depth += 1
        indentation.append(indent)

    elif indent < indentation[-1]:
        while indent < indentation[-2]:
            depth -= 1
            indentation.pop()

        #if indent != indentation[-1]:
        #    raise RuntimeError("Bad formatting")

    print(f"{content} (depth: {depth})")
# Out:
# Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided (depth: 0)
# Natural language processing | natural language processing, nlp (depth: 1)
# Syntactic analysis | (depth: 2)
# Grammar induction | grammar induction,grammar learning (depth: 2)
# Stemming | (depth: 3)
# Lemmatization | (depth: 3)
# Morphological segmentation | (depth: 3)
# Part-of-speech tagging | part of speech tagging,pos tagging (depth: 3)
# Syntactic Parsing | (depth: 3)
# Sentence boundary disambiguation | sentence boundary disambiguation,sentence breaking (depth: 3)
# Word segmentation | (depth: 3)
# Terminology extraction | (depth: 3)
# Semantic analysis | (depth: 3)
# Lexical semantics | (depth: 3)
# Distributional semantics | (depth: 3)
# Machine Translation | (depth: 3)
# Named entity recognition |  ner ,entity recognition (depth: 3)
# Natural language generation | natural language generation, nlg (depth: 3)
# Question answering | (depth: 3)
# Sentiment analysis | (depth: 3)
# Topic segmentation | (depth: 3)
# Word sense disambiguation | (depth: 3)
# Ontology learning | (depth: 3)
# Word embedding | (depth: 3)
# Bag-of-words model | bag of words (depth: 3)
# Context recognition | (depth: 3)
# Discourse, dialogue and pragmatics | (depth: 3)
# Text summarization | (depth: 3)
# Text mining | (depth: 3)
# Text classification | (depth: 3)
# Discourse analysis | (depth: 3)
# Speech recognition | (depth: 3)
# empty (depth: 3)
# Logic, knowledge representation and reasoning | rule based,logic,reasoning,knowledge representation (depth: 1)
# Rule-based reasoning | rule based (depth: 1)
# Hand-crafted rules | (depth: 2)
# Proof theory | (depth: 2)
# Modal and temporal logics | modal logic,temporal logic (depth: 2)
# Automated reasoning | (depth: 2)
# Constraint and logic programming | constraint programming,logic programming (depth: 2)
# Constructive mathematics | (depth: 2)
# Description logics | (depth: 2)
# Equational logic and rewriting | equational logic (depth: 2)
# Finite Model Theory | (depth: 2)
# Higher order logic | (depth: 2)
# Linear logic | (depth: 2)
# Programming logic | (depth: 2)
# Verification by model checking | (depth: 2)
# Type theory | (depth: 2)
# Hoare logic | (depth: 2)
# Separation logic | (depth: 2)
# Semantic networks | (depth: 2)
# Nonmonotonic, default reasoning and belief revision | nonmonotonic reasoning,default reasoning,belief revision (depth: 2)
# Probabilistic reasoning | (depth: 2)
# Vagueness and fuzzy logic | fuzzy logic (depth: 2)
# Causal reasoning | (depth: 2)
# Temporal reasoning | (depth: 2)
# Cognitive robotics | (depth: 2)
# Ontology engineering | (depth: 2)
# Logic programming and answer set programming | logic programming,answer set programming (depth: 2)
# Spatial and physical reasoning | spatial reasoning,physical reasoning (depth: 2)
# Case-based reasoning | (depth: 2)
# Constraint-based reasoning | (depth: 2)
# Propositional logic | propositional logic,statement logic,sentential logic (depth: 2)
# First-order logic | first order logic,predicate logic,quantificational logic (depth: 2)
# Abductive reasoning | (depth: 2)
# Analogical reasoning | (depth: 2)
# Searching, planning and scheduling | search algorithm,automated planning,automated scheduling (depth: 1)
# Planning for deterministic actions | deterministic planning (depth: 1)
# State-space search | (depth: 2)
# Forward search | (depth: 2)
# Backward search | (depth: 2)
# Heuristic search algorithms | heuristic search (depth: 2)
# Planning under uncertainty | non deterministic planning (depth: 2)
# Systematic nonlinear planning | systematic nonlinear planning, snlp (depth: 2)
# Multi-agent planning | (depth: 2)
# Robotic planning | (depth: 2)
# Evolutionary robotics | (depth: 3)
# Heuristic function construction | heuristic function (depth: 2)
# Discrete space search | (depth: 2)
# Continuous space search | (depth: 2)
# Randomized search | (depth: 2)
# Tree search  | (depth: 2)
# Distributed artificial intelligence | (depth: 2)
# Multi-agent systems | (depth: 2)
# Intelligent agents | (depth: 2)
# Mobile agents | (depth: 2)
# Cooperation and coordination | (depth: 2)
# Parallel and distributed algorithms | parallel algorithm,distributed algorithm (depth: 2)
# MapReduce algorithms | (depth: 3)
# Self-organization | (depth: 3)
# Shared memory algorithms | (depth: 3)
# Vector and streaming algorithms | vector algorithm,streaming algorithm (depth: 3)
# Massively parallel algorithms | (depth: 3)
# Swarm intelligence | (depth: 3)
# Ant colony optimization | (depth: 3)
# Particle swarm optimization | (depth: 3)
# Computer vision | computer vision,machine perception (depth: 1)
# Image recognition | (depth: 2)
# Biometrics | (depth: 2)
# Scene understanding | (depth: 2)
# Activity recognition and understanding | activity recognition,activity understanding (depth: 2)
# Gesture recognition | (depth: 3)
# Motion recognition | (depth: 4)
# Facial recognition  | (depth: 4)
# Emotion detection | (depth: 4)
# Video summarization | (depth: 3)
# Visual content-based indexing and retrieval | visual content based indexing,visual content based retrieval (depth: 2)
# Visual inspection | (depth: 2)
# Vision for robotics | robotic vision,robot vision,robot perception (depth: 2)
# Scene anomaly detection | (depth: 2)
# Interest point and salient region detections | interest point detection,salient region detection (depth: 2)
# Image segmentation | image segmentation,automated segmentation (depth: 2)
# Image analysis | image analysis,image processing,image analytics (depth: 2)
# Video segmentation | (depth: 2)
# Shape inference | (depth: 2)
# Object detection and recognition | object detection,object identification,object recognition,obstacle recognition (depth: 2)
# Spatial recognition | (depth: 2)
# Tracking | visual tracking,object tracking (depth: 2)
# Reconstruction | image reconstruction,3d reconstruction (depth: 2)
# Matching | image matching,feature matching,template matching (depth: 2)
# Machine learning | machine learning, ml ,learning algorithm,prediction algorithm,prediction model,knowledge aquisition,knowledge extraction (depth: 1)
# Learning paradigms | (depth: 2)
# Supervised learning |  supervised learning,imitation learning (depth: 2)
# Learning to rank | learning to rank,machine learned ranking (depth: 3)
# Supervised learning by classification | classification, classifier (depth: 3)
# Multi-class classification | (depth: 4)
# Regression | (depth: 4)
# Structured outputs | (depth: 4)
# Cost-sensitive learning | (depth: 4)
# Unsupervised learning | unsupervised learning,self learning (depth: 3)
# Cluster analysis | cluster analysis,clustering (depth: 3)
# Anomaly detection | (depth: 4)
# Mixture modeling | mixture model,mixed model (depth: 4)
# Topic modeling | (depth: 4)
# Source separation | (depth: 4)
# Motif discovery | (depth: 4)
# Dimensionality reduction and manifold learning | dimensionality reduction,manifold learning (depth: 4)
# Semi-supervised learning | (depth: 4)
# Reinforcement learning | (depth: 4)
# Sequential decision making | (depth: 4)
# Inverse reinforcement learning | (depth: 4)
# Apprenticeship learning | (depth: 4)
# Multi-agent reinforcement learning | (depth: 4)
# Adversarial learning | (depth: 4)
# Multi-task learning | (depth: 4)
# Transfer learning | (depth: 4)
# Lifelong machine learning | (depth: 4)
# Learning under covariate shift | (depth: 4)
# Deep learning | (depth: 4)
# Machine learning approaches and algorithms | learning algorithm,learning model,learning approach (depth: 2)
# Classification and regression trees | classification algorithm,regression tree (depth: 2)
# Decision trees | (depth: 3)
# Ensemble methods | ensemble (depth: 3)
# Boosting | (depth: 4)
# Bagging | (depth: 4)
# Random forest | (depth: 4)
# Gradient boosting | (depth: 4)
# k-nearest-neighbor algorithm | k nearest neighbor, k nn (depth: 4)
# Perceptron algorithm | perceptron (depth: 3)
# Clustering algorithms | (depth: 3)
# K-means |  k means (depth: 3)
# Density-based algorithms | (depth: 3)
# DBSCAN | (depth: 4)
# Hierarchical clustering | (depth: 4)
# Agglomerative hierarchical clustering | agglomerative hierarchical clustering,agglomerative clustering (depth: 4)
# Divisive hierarchical clustering | divisive hierarchical clustering,divisive clustering (depth: 4)
# Kernel methods | (depth: 3)
# Support vector machines | support vector, svm (depth: 3)
# Gaussian processes | (depth: 3)
# Gaussian naive bayes  | gaussian naive bayes,gaussian na ve bayes,gaussian naïve bayes (depth: 3)
# Artificial neural networks | neural network, nn , ann (depth: 3)
# Autoencoder | (depth: 3)
# Multilayer perceptron | (depth: 3)
# Deep neural network  | deep neural network, dnn (depth: 3)
# Deep belief network | (depth: 3)
# Recurrent neural network | recurrent neural network, rnn (depth: 3)
# Long short term memory network | long short term memory network, lstm (depth: 4)
# Generative adversarial network | generative adversarial network, gan (depth: 4)
# Convolutional neural network | convolutional neural network, cnn (depth: 4)
# Self-organizing map | self organizing map, som (depth: 4)
# Feed-forward neural network | feed forward neural network,constructive neural network (depth: 3)
# Spiking neural network | spiking neural network, snn (depth: 3)
# Radial basis function network | radial basis function network,radial basis network,rbf network (depth: 3)
# Logical and relational learning | logical learning,relational learning (depth: 3)
# Inductive logic learning | inductive logic learning,inductive learning (depth: 3)
# Statistical relational learning | statistical relational learning,statistical learning (depth: 3)
# Association rule learning | association rule learning,association learning (depth: 3)
# Learning in probabilistic graphical models | learning graphical model (depth: 3)
# Maximum likelihood modeling | maximum likelihood (depth: 3)
# Maximum entropy modeling | maximum entropy (depth: 3)
# Maximum a posteriori modeling | maximum a posteriori (depth: 3)
# Latent variable models | latent variable (depth: 3)
# Bayesian network models | bayesian network,bayesian model (depth: 3)
# Naive bayes classifier | naive bayes classifier,na ve bayes classifier,naïve bayes classifier (depth: 3)
# Factorization methods | (depth: 3)
# Non-negative matrix factorization | non negative matrix factorization,non-negative matrix approximation, nmf , nnmf (depth: 3)
# Factor analysis | (depth: 3)
# Principal component analysis | principal component analysis, pca (depth: 3)
# Canonical correlation analysis | (depth: 3)
# Latent Dirichlet allocation | (depth: 3)
# Linear discriminant analysis | (depth: 3)
# Rule learning | (depth: 3)
# Instance-based learning | instance based learning,memory based learning (depth: 3)
# Bio-inspired approaches | (depth: 3)
# Artificial life | (depth: 3)
# Artificial immune system | (depth: 3)
# Evolvable hardware | (depth: 3)
# Genetic algorithms | (depth: 3)
# Genetic programming | (depth: 3)
# Evolutionary robotics | (depth: 3)
# Generative and developmental approaches | generative approach,developmental approach (depth: 3)
# Dynamic programming for Markov decision processes | Markov decision process, mdp (depth: 3)
# Multi-armed bandit algorithm | armed bandit (depth: 3)
# Value iteration | (depth: 3)
# Q-learning | (depth: 3)
# Policy iteration | (depth: 3)
# Temporal difference learning | (depth: 3)
# Approximate dynamic programming methods | (depth: 3)
# Spectral methods | (depth: 3)
# Feature engineering | (depth: 3)
# Feature extraction | (depth: 3)
# Feature projection | (depth: 3)
# Feature learning | (depth: 3)
# Feature selection | (depth: 3)
# Regularization | (depth: 3)
# Modeling and simulation | modeling,simulation (depth: 1)
# Model development and analysis | model development,model analysis (depth: 1)
# Modeling methodologies | (depth: 2)
# Model verification and validation | model verification,model validation (depth: 2)
# Uncertainty quantification | (depth: 2)
# Simulation types and techniques | simulation technique (depth: 2)
# Uncertainty quantification | (depth: 2)
# Quantum mechanic simulation | (depth: 2)
# Molecular simulation | (depth: 2)
# Rare-event simulation | (depth: 2)
# Discrete-event simulation | (depth: 2)
# Agent and discrete models | agent model,discrete model (depth: 2)
# Distributed simulation | (depth: 2)
# Continuous simulation | (depth: 2)
# Continuous models | (depth: 2)
# Real-time simulation | (depth: 2)
# Interactive simulation | (depth: 2)
# Multiscale systems | (depth: 2)
# Massively parallel and high-performance simulations | massively parallel simulation,high-performance simulation (depth: 2)
# Data assimilation | (depth: 2)
# Scientific visualization | (depth: 2)
# Visual analytics | (depth: 2)
# Simulation by animation | (depth: 2)
# Artificial life | (depth: 2)
# Mathematical algorithms and methods | mathematical (depth: 1)
# Symbolic and algebraic algorithms | (depth: 2)
# Combinatorial algorithms | combinatorial (depth: 2)
# Algebraic algorithms | algebraic (depth: 2)
# Nonalgebraic algorithms | nonalgebraic (depth: 2)
# Symbolic calculus algorithms | symbolic calculus (depth: 2)
# Exact arithmetic algorithms | exact arithmetic (depth: 2)
# Hybrid symbolic-numeric methods | hybrid symbolic-numeric (depth: 2)
# Discrete calculus algorithms | discrete calculus (depth: 2)
# Number theory algorithms | number theory (depth: 2)
# Equation and inequality solving algorithms | equation solving,inequality solving (depth: 2)
# Linear algebra algorithms | linear algebra (depth: 2)
# Theorem proving algorithms | theorem proving (depth: 2)
# Boolean algebra algorithms | boolean algebra (depth: 2)
# Optimization algorithms | (depth: 3)
# Graph theory | (depth: 3)
# Trees | (depth: 3)
# Hypergraphs | (depth: 3)
# Random graphs | (depth: 3)
# Graph coloring | (depth: 3)
# Paths and connectivity problems | pathfinding,graph connect,graph search (depth: 3)
# Graph enumeration | (depth: 3)
# Matchings and factors | graph matching,graph factors (depth: 3)
# Spectra of graphs | (depth: 3)
# Extremal graph theory | (depth: 3)
# Matroids and greedoids | matroid,greedoid (depth: 3)
# Graph algorithms | (depth: 3)
# Approximation | graph approximation (depth: 3)
# Backpropagation | (depth: 3)
# Graph algorithms analysis | (depth: 3)
# Network flows | network flow,network graph (depth: 3)
# Sparsification and spanners | graph sparsification,graph spanner (depth: 3)
# Shortest paths | (depth: 4)
# Dynamic graph algorithms | (depth: 4)
# Probability and statistics | statistical analysis (depth: 2)
# Probabilistic representations | (depth: 3)
# Bayesian networks | (depth: 4)
# Markov networks | (depth: 4)
# Factor graphs | (depth: 4)
# Decision diagrams | (depth: 4)
# Equational models | (depth: 4)
# Causal networks | (depth: 4)
# Stochastic differential equations | (depth: 4)
# Autoregressive model | (depth: 4)
# Nonparametric representations | (depth: 4)
# Kernel density estimators | (depth: 5)
# Spline models | (depth: 5)
# Bayesian nonparametric models | (depth: 5)
# Probabilistic inference problems | probabilistic inference (depth: 3)
# Maximum likelihood estimation | (depth: 4)
# Bayesian computation | bayesian computation,bayesian analysis (depth: 4)
# Computing most probable explanation | (depth: 4)
# Hypothesis testing and confidence interval computation | hypothesis testing,confidence interval computation (depth: 4)
# Density estimation | (depth: 4)
# Quantile regression | (depth: 5)
# Max marginal computation | (depth: 5)
# Probabilistic reasoning algorithms | probabilistic reasoning (depth: 3)
# Variable elimination | (depth: 4)
# Loopy belief propagation | (depth: 4)
# Variational methods | (depth: 4)
# Expectation maximization | (depth: 4)
# Markov-chain Monte Carlo methods | markov chain monte carlo (depth: 4)
# Gibbs sampling | (depth: 5)
# Metropolis-Hastings algorithm | (depth: 5)
# Simulated annealing | (depth: 5)
# Markov-chain Monte Carlo convergence measures | markov chain monte carlo convergence (depth: 5)
# Sequential Monte Carlo methods | (depth: 5)
# Kalman filters and hidden Markov models | kalman filter,hidden markov model (depth: 4)
# Resampling methods | (depth: 4)
# Bootstrapping | (depth: 5)
# Jackknifing | jackknif (depth: 5)
# Random number generation | random number generation, rng (depth: 5)
# Probabilistic algorithms | (depth: 4)
# Statistical paradigms | (depth: 4)
# Queueing theory | (depth: 4)
# Contingency table analysis | (depth: 4)
# Regression analysis | (depth: 4)
# Robust regression | (depth: 5)
# Linear regression | (depth: 5)
# Bayesian regression | (depth: 6)
# Logistic Regression | (depth: 6)
# Lasso regression | (depth: 6)
# Poisson regression | (depth: 6)
# Binomial regression | (depth: 6)
# Time series analysis | (depth: 5)
# Survival analysis | (depth: 5)
# Cox proportional hazards model | cox regression,cox proportional hazards (depth: 5)
# Renewal theory | (depth: 5)
# Statistical graphics | (depth: 5)
# Exploratory data analysis | (depth: 5)
# Nonparametric statistics | (depth: 4)
# Distribution functions | (depth: 4)
# Univariate statistics | univariate (depth: 3)
# Multivariate statistics | multivariate,multivariable (depth: 3)
# Mathematical software | (depth: 3)
# Solvers | (depth: 3)
# Statistical software | (depth: 3)
# Mathematical analysis | (depth: 3)
# Numerical analysis | (depth: 3)
# Computation of transforms | transformation (depth: 3)
# Computations in finite fields | finite field (depth: 3)
# Computations on matrices | matrix,matrices (depth: 3)
# Computations on polynomials | gröbner bases,polynomial (depth: 3)
# Number-theoretic computations | (depth: 4)
# Interpolation | (depth: 4)
# Numerical differentiation | (depth: 4)
# Interval arithmetic | (depth: 4)
# Arbitrary-precision arithmetic | (depth: 4)
# Automatic differentiation | (depth: 4)
# Mesh generation | (depth: 4)
# Discretization | (depth: 4)
# Mathematical optimization | (depth: 4)
# Discrete optimization | (depth: 4)
# Network optimization | (depth: 5)
# Optimization with randomized search heuristics | random optimization, randomized search heuristic (depth: 5)
# Simulated annealing | (depth: 6)
# Evolutionary algorithms | evolutionary computation,evolutionary algorithm (depth: 6)
# Tabu search | (depth: 6)
# Randomized local search | (depth: 6)
# Hill climbing | (depth: 6)
# Beam search | (depth: 6)
# Continuous optimization | (depth: 5)
# Dynamic programming | (depth: 5)
# Linear programming | (depth: 5)
# Semidefinite programming | (depth: 5)
# Convex optimization | (depth: 5)
# Quasiconvex programming and unimodality | quasiconvex programming,unimodality (depth: 5)
# Stochastic control and optimization | stochastic control, stochastic optimization (depth: 5)
# Quadratic programming | (depth: 5)
# Nonconvex optimization | (depth: 5)
# Bio-inspired optimization | (depth: 5)
# Mixed discrete-continuous optimization | (depth: 5)
# Submodular optimization and polymatroids | submodular optimization,polymatroids (depth: 5)
# Integer programming | (depth: 5)
# Algorithmic game theory and mechanism design | game theory,mechanism design (depth: 1)
# Algorithmic game theory | game theory (depth: 1)
# Computation of equilibria | computation of equilibri,equilibria computation,equilibrium computation (depth: 1)
# Nash equilibria | nash equilibri (depth: 1)
# Quality of equilibria | Quality of equilibri,efficiency of equilibri (depth: 1)
# Algorithmic mechanism design | mechanism design (depth: 1)
# Social networks | social network,soial choice (depth: 1)
# Convergence and learning in games | convergence in game,learning in game (depth: 1)
# Market equilibria | market equilibri (depth: 1)
# Computational pricing and auctions | Computational pricing,computational auction (depth: 1)
# Network games | (depth: 2)
# Network formation | (depth: 2)
# Computational advertising theory | computational advertising (depth: 2)
# Information retrieval and data mining | information retrieval,data mining,big data,data science,data extraction (depth: 1)
# Data structures design and analysis | data analysis,data analytics (depth: 1)
# Data compression | (depth: 2)
# Pattern matching | (depth: 2)
# Sorting and searching | data sorting,data searching (depth: 2)
# Predecessor queries | (depth: 2)
# Cell probe models and lower bounds | cell probe model,lower bounds (depth: 2)
# Database theory | (depth: 2)
# Data exchange | (depth: 3)
# Data provenance | (depth: 3)
# Data modeling | (depth: 3)
# Database query languages | (depth: 3)
# Database constraints theory | (depth: 3)
# Database interoperability | (depth: 3)
# Data structures and algorithms for data management | data management (depth: 3)
# Database query processing and optimization | query processing,query optimization (depth: 3)
# Data integration | (depth: 3)
# Logic and databases | (depth: 3)
# Database privacy and security | database privacy, database security (depth: 3)
# Incomplete, inconsistent, and uncertain databases | incomplete database,inconsistent database,uncertain database (depth: 3)
# Information retrieval query processing | query processing (depth: 2)
# Query representation | (depth: 2)
# Query intent | (depth: 2)
# Query log analysis | (depth: 2)
# Query suggestion | (depth: 2)
# Query reformulation | (depth: 2)
# Users and interactive retrieval | interactive retrieval (depth: 2)
# Personalization | personalized information retrieval (depth: 2)
# Task models | (depth: 2)
# Search interfaces | (depth: 2)
# Collaborative search | (depth: 2)
# Retrieval models and ranking | retrieval model,ranking (depth: 2)
# Rank aggregation | (depth: 2)
# Probabilistic retrieval models | probabilistic retrieval (depth: 2)
# Language models | (depth: 2)
# Similarity measures | (depth: 2)
# Learning to rank | (depth: 2)
# Combination, fusion and federated search | federated search,data fusion,data combin (depth: 2)
# Information retrieval diversity | retrieval diversity (depth: 2)
# Top-k retrieval in databases | top k retrieval (depth: 2)
# Novelty in information retrieval | (depth: 2)
# Retrieval tasks and goals | retrieval task,retrieval goal (depth: 2)
# Question answering | (depth: 2)
# Document filtering | (depth: 2)
# Recommender systems | (depth: 2)
# Information extraction | (depth: 2)
# Sentiment analysis | (depth: 2)
# Expert search | (depth: 2)
# Near-duplicate and plagiarism detection | near duplicate detection,plagiarism detection (depth: 2)
# Clustering | cluster (depth: 2)
# Classification | classifi (depth: 2)
# Summarization | text summar,document summar,data summar (depth: 2)
# Business intelligence | (depth: 2)
# Evaluation of retrieval results | (depth: 2)
# Test collections | (depth: 2)
# Relevance assessment | (depth: 2)
# Retrieval effectiveness | (depth: 2)
# Retrieval efficiency | (depth: 2)
# Presentation of retrieval results | (depth: 2)
# Search engine architectures and scalability | search engine architecture,search engine scalability (depth: 2)
# Search engine indexing | (depth: 2)
# Search index compression | (depth: 2)
# Distributed retrieval | (depth: 2)
# Peer-to-peer retrieval | (depth: 2)
# Retrieval on mobile devices | (depth: 2)
# Adversarial retrieval | (depth: 2)
# Link and co-citation analysis | link analysis,citation analysis (depth: 2)
# Searching with auxiliary databases | auxiliary database (depth: 2)
# Specialized information retrieval | (depth: 2)
# Structured and multilingual text search | (depth: 2)
# Structured text search | (depth: 3)
# Mathematics retrieval | (depth: 3)
# Chemical and biochemical retrieval | chemical retrieval (depth: 3)
# Multilingual and cross-lingual retrieval | lingual retrieval (depth: 3)
# Multimedia and multimodal retrieval | multimedia retrieval,multimodal retrieval (depth: 2)
# Image search | image search,image retrieval (depth: 2)
# Video search | video search,video retrieval (depth: 2)
# Speech and audio search | speech search,audio search,speech retrieval,audio retrieval (depth: 2)
# Music retrieval | music retrieval,music search (depth: 2)
# Environment-specific retrieval | (depth: 2)
# Enterprise search | (depth: 3)
# Desktop search | (depth: 3)
# Web mining | web mining,web retrieval (depth: 2)
# Site wrapping | (depth: 3)
# Data extraction and integration | web data extraction,web data integration (depth: 3)
# Deep web | (depth: 4)
# Surfacing | (depth: 4)
# Search results deduplication | (depth: 4)
# Web log analysis | (depth: 4)
# Traffic analysis | (depth: 4)
# Web crawling | (depth: 4)
# Web indexing | (depth: 4)
# Page and site ranking | page ranking,site ranking (depth: 3)
# Spam detection | (depth: 3)
# Human-centered computing | (depth: 2)
# Cognitive computing | (depth: 2)
# Affective computing | (depth: 2)
# Human computer interaction |  hci ,human machine interaction,human machine interface,human computer interface (depth: 2)
# Interaction paradigms | (depth: 2)
# Hypertext and hypermedia | hypertext,hypermedia (depth: 2)
# Mixed and augmented reality | mixed reality,augmented reality (depth: 2)
# Command line interfaces | (depth: 3)
# Graphical user interfaces | graphical user interface, gui (depth: 3)
# Virtual reality | (depth: 3)
# Virtual assistants | (depth: 3)
# Chatbots | (depth: 3)
# Question answering systems | question answering (depth: 3)
# Decision support systems | decision support,decision model (depth: 3)
# Expert systems | (depth: 4)
# Web-based interaction | web based communication,web based interaction,online communication (depth: 3)
# Digital assistants | (depth: 3)
# Natural language interfaces | (depth: 3)
# Collaborative interaction | (depth: 3)
# Interaction techniques | (depth: 3)
# Auditory feedback | (depth: 3)
# Text input | (depth: 3)
# Pointing | (depth: 3)
# Gestural input | gestural input,gesture input,gesture recognition (depth: 3)
# Ubiquitous and mobile computing | (depth: 2)
# Ubiquitous and mobile computing theory, concepts and paradigms | (depth: 2)
# Ubiquitous computing | ubiquitous,pervasive,mobile computing (depth: 2)
# Mobile computing | mobile computing,mobile app, smartphone app (depth: 2)
# Ambient intelligence | (depth: 3)
# Internet-of-things | (depth: 3)
# Location based services | (depth: 3)
# Smart applications | smart (depth: 2)
# Smart city | (depth: 3)
# Smart home | (depth: 3)
# Smart device | (depth: 3)
# Wearables | (depth: 3)
# Embedded and cyber-physical systems | embedded,cyber physical (depth: 1)
# Sensors and actuators | sensor,actuator (depth: 1)
# Sensor data | (depth: 2)
# Sensor networks | sensor network,sensor system (depth: 2)
# Sensor fusion | (depth: 3)
# Robotics | robot (depth: 2)
# Robotic components | (depth: 2)
# Robotic control | (depth: 2)
# Evolutionary robotics | (depth: 3)
# Robotic autonomy | autonomous robot,robotic autonomy (depth: 2)
# Brain-computer interfaces | brain computer interface, bci (depth: 2)
# Neuroprosthetics | (depth: 2)
# Robot-assisted surgery | robotic assisted,robot assisted (depth: 2)
# Autonomous vehicles | autonomous vehicle,self driving (depth: 2)
# Humanoid robots | (depth: 2)
# System on a chip | (depth: 2)
# Embedded systems | (depth: 2)
# Firmware | (depth: 2)
# Embedded hardware | (depth: 2)
# Embedded software | (depth: 2)
# Healthcare and medicine specific applications | (depth: 2)
# Computational chemistry | (depth: 2)
# Computational biology | (depth: 2)
# Molecular sequence analysis | (depth: 2)
# Molecular evolution | (depth: 2)
# Biological networks | (depth: 2)
# Molecular structural biology | (depth: 2)
# Genetics and Genomics | genetic analysis,gene analysis,genome analysis,genetic model,genome interpretation (depth: 2)
# Proteomics | proteomic analysis,proteomic profiling,proteome profiling (depth: 2)
# Pathway analysis | (depth: 3)
# Gene ontology analysis | gene ontology (depth: 3)
# Gene set enrichment analysis | enrichment analysis,gene ontology term enrichment (depth: 3)
# Gene expression profiling | gene profiling,genetic profiling,expression profiling,gene expression analysis,dna seq (depth: 3)
# Microarray analysis | (depth: 4)
# Transcriptomics | transcriptomics,transcriptome profiling,transcriptomic profiling,transcriptome sequencing,transcriptomic analysis,transcriptome analysis (depth: 4)
# RNA sequencing |  rna seq, rna analysis] (depth: 4)
# miRNA sequencing | mirna seq,mirna analysis] (depth: 4)
# Whole genome sequencing | genome sequencing (depth: 4)
# Exome sequencing | (depth: 4)
# High-throughput methods | high throughput (depth: 4)
# Long-read sequencing | (depth: 5)
# Short-read sequencing | (depth: 5)
# Gene prediction | gene prediction,genetic prediction (depth: 3)
# Polygenic score | polygenic score,polygenic risk score,polygenic risk prediction (depth: 3)
# Genotype-to-phenotype prediction | phenotype prediction (depth: 3)
# Phenotype-to-genotype mapping | genotype mapping (depth: 3)
# DNA annotation | dna annotation, genome annotation (depth: 3)
# Systems biology | (depth: 2)
# Consumer health | (depth: 2)
# Health care information systems | (depth: 2)
# Health informatics | (depth: 2)
# Bioinformatics | (depth: 2)
# Bioengineering | (depth: 2)
# Metabolomics and metabonomics | metabolomics,metabonomic (depth: 2)

# %%
indentation = []
indentation.append(0)
depth = 0

f = open("acm_hierarchy_restructure.txt", 'r')

for line in f:
    line = line[:-1]

    content = line.strip()
    indent = len(line) - len(content)
    if indent > indentation[-1]:
        depth += 1
        indentation.append(indent)
        data.append([])

    elif indent < indentation[-1]:
        while indent < indentation[-1]:
            depth -= 1
            indentation.pop()
            top = data.pop()
            data[-1].append(top)

        #if indent != indentation[-3]:
        #    raise RuntimeError("Bad formatting")

    data[-1].append(content)

while len(data) > 1:
    top = data.pop()
    data[-1].append(top)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-03b6dcb34b96> in <module>
#      25         #    raise RuntimeError("Bad formatting")
#      26
# ---> 27     algorithm[-1].append(content)
#      28
#      29 while len(algorithm) > 1:
#
# NameError: name 'algorithm' is not defined

# %%
data
# Out:
# [[[[]],
#   [],
#   [[], []],
#   [[[]]],
#   [[[], []], [[], [], []]],
#   [],
#   [[[]], [[[]], [[]], [[], [], [[]]], [[[]]]]],
#   [],
#   [[], [], [], [[]], [[]], [], []],
#   [[], [], [[[]]]],
#   'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#   ['Natural language processing | natural language processing, nlp',
#    ['Syntactic analysis |',
#     'Grammar induction | grammar induction,grammar learning',
#     ['Stemming |',
#      'Lemmatization |',
#      'Morphological segmentation |',
#      'Part-of-speech tagging | part of speech tagging,pos tagging',
#      'Syntactic Parsing |',
#      'Sentence boundary disambiguation | sentence boundary disambiguation,sentence breaking',
#      'Word segmentation |',
#      'Terminology extraction |',
#      'Semantic analysis |',
#      'Lexical semantics |',
#      'Distributional semantics |',
#      'Machine Translation |',
#      'Named entity recognition |  ner ,entity recognition',
#      'Natural language generation | natural language generation, nlg',
#      'Question answering |',
#      'Sentiment analysis |',
#      'Topic segmentation |',
#      'Word sense disambiguation |',
#      'Ontology learning |',
#      'Word embedding |',
#      'Bag-of-words model | bag of words',
#      'Context recognition |',
#      'Discourse, dialogue and pragmatics |',
#      'Text summarization |',
#      'Text mining |',
#      'Text classification |',
#      'Discourse analysis |'],
#     'Speech recognition |'],
#    'Logic, knowledge representation and reasoning | rule based,logic,reasoning,knowledge representation',
#    'Rule-based reasoning | rule based',
#    ['Hand-crafted rules |',
#     'Proof theory |',
#     'Modal and temporal logics | modal logic,temporal logic',
#     'Automated reasoning |',
#     'Constraint and logic programming | constraint programming,logic programming',
#     'Constructive mathematics |',
#     'Description logics |',
#     'Equational logic and rewriting | equational logic',
#     'Finite Model Theory |',
#     'Higher order logic |',
#     'Linear logic |',
#     'Programming logic |',
#     'Verification by model checking |',
#     'Type theory |',
#     'Hoare logic |',
#     'Separation logic |',
#     'Semantic networks |',
#     'Nonmonotonic, default reasoning and belief revision | nonmonotonic reasoning,default reasoning,belief revision',
#     'Probabilistic reasoning |',
#     'Vagueness and fuzzy logic | fuzzy logic',
#     'Causal reasoning |',
#     'Temporal reasoning |',
#     'Cognitive robotics |',
#     'Ontology engineering |',
#     'Logic programming and answer set programming | logic programming,answer set programming',
#     'Spatial and physical reasoning | spatial reasoning,physical reasoning',
#     'Case-based reasoning |',
#     'Constraint-based reasoning |',
#     'Propositional logic | propositional logic,statement logic,sentential logic',
#     'First-order logic | first order logic,predicate logic,quantificational logic',
#     'Abductive reasoning |',
#     'Analogical reasoning |'],
#    'Searching, planning and scheduling | search algorithm,automated planning,automated scheduling',
#    'Planning for deterministic actions | deterministic planning',
#    ['State-space search |',
#     'Forward search |',
#     'Backward search |',
#     'Heuristic search algorithms | heuristic search',
#     'Planning under uncertainty | non deterministic planning',
#     'Systematic nonlinear planning | systematic nonlinear planning, snlp',
#     'Multi-agent planning |',
#     'Robotic planning |',
#     ['Evolutionary robotics |'],
#     'Heuristic function construction | heuristic function',
#     'Discrete space search |',
#     'Continuous space search |',
#     'Randomized search |',
#     'Tree search  |',
#     'Distributed artificial intelligence |',
#     'Multi-agent systems |',
#     'Intelligent agents |',
#     'Mobile agents |',
#     'Cooperation and coordination |',
#     'Parallel and distributed algorithms | parallel algorithm,distributed algorithm',
#     ['MapReduce algorithms |',
#      'Self-organization |',
#      'Shared memory algorithms |',
#      'Vector and streaming algorithms | vector algorithm,streaming algorithm',
#      'Massively parallel algorithms |',
#      'Swarm intelligence |',
#      'Ant colony optimization |',
#      'Particle swarm optimization |']],
#    'Computer vision | computer vision,machine perception',
#    ['Image recognition |',
#     'Biometrics |',
#     'Scene understanding |',
#     'Activity recognition and understanding | activity recognition,activity understanding',
#     ['Gesture recognition |',
#      ['Motion recognition |', 'Facial recognition  |', 'Emotion detection |'],
#      'Video summarization |'],
#     'Visual content-based indexing and retrieval | visual content based indexing,visual content based retrieval',
#     'Visual inspection |',
#     'Vision for robotics | robotic vision,robot vision,robot perception',
#     'Scene anomaly detection |',
#     'Interest point and salient region detections | interest point detection,salient region detection',
#     'Image segmentation | image segmentation,automated segmentation',
#     'Image analysis | image analysis,image processing,image analytics',
#     'Video segmentation |',
#     'Shape inference |',
#     'Object detection and recognition | object detection,object identification,object recognition,obstacle recognition',
#     'Spatial recognition |',
#     'Tracking | visual tracking,object tracking',
#     'Reconstruction | image reconstruction,3d reconstruction',
#     'Matching | image matching,feature matching,template matching'],
#    'Machine learning | machine learning, ml ,learning algorithm,prediction algorithm,prediction model,knowledge aquisition,knowledge extraction',
#    ['Learning paradigms |',
#     'Supervised learning |  supervised learning,imitation learning',
#     ['Learning to rank | learning to rank,machine learned ranking',
#      'Supervised learning by classification | classification, classifier',
#      ['Multi-class classification |',
#       'Regression |',
#       'Structured outputs |',
#       'Cost-sensitive learning |'],
#      'Unsupervised learning | unsupervised learning,self learning',
#      'Cluster analysis | cluster analysis,clustering',
#      ['Anomaly detection |',
#       'Mixture modeling | mixture model,mixed model',
#       'Topic modeling |',
#       'Source separation |',
#       'Motif discovery |',
#       'Dimensionality reduction and manifold learning | dimensionality reduction,manifold learning',
#       'Semi-supervised learning |',
#       'Reinforcement learning |',
#       'Sequential decision making |',
#       'Inverse reinforcement learning |',
#       'Apprenticeship learning |',
#       'Multi-agent reinforcement learning |',
#       'Adversarial learning |',
#       'Multi-task learning |',
#       'Transfer learning |',
#       'Lifelong machine learning |',
#       'Learning under covariate shift |',
#       'Deep learning |']],
#     'Machine learning approaches and algorithms | learning algorithm,learning model,learning approach',
#     'Classification and regression trees | classification algorithm,regression tree',
#     ['Decision trees |',
#      'Ensemble methods | ensemble',
#      ['Boosting |',
#       'Bagging |',
#       'Random forest |',
#       'Gradient boosting |',
#       'k-nearest-neighbor algorithm | k nearest neighbor, k nn'],
#      'Perceptron algorithm | perceptron',
#      'Clustering algorithms |',
#      'K-means |  k means',
#      'Density-based algorithms |',
#      ['DBSCAN |',
#       'Hierarchical clustering |',
#       'Agglomerative hierarchical clustering | agglomerative hierarchical clustering,agglomerative clustering',
#       'Divisive hierarchical clustering | divisive hierarchical clustering,divisive clustering'],
#      'Kernel methods |',
#      'Support vector machines | support vector, svm',
#      'Gaussian processes |',
#      'Gaussian naive bayes  | gaussian naive bayes,gaussian na ve bayes,gaussian naïve bayes',
#      'Artificial neural networks | neural network, nn , ann',
#      'Autoencoder |',
#      'Multilayer perceptron |',
#      'Deep neural network  | deep neural network, dnn',
#      'Deep belief network |',
#      'Recurrent neural network | recurrent neural network, rnn',
#      ['Long short term memory network | long short term memory network, lstm',
#       'Generative adversarial network | generative adversarial network, gan',
#       'Convolutional neural network | convolutional neural network, cnn',
#       'Self-organizing map | self organizing map, som'],
#      'Feed-forward neural network | feed forward neural network,constructive neural network',
#      'Spiking neural network | spiking neural network, snn',
#      'Radial basis function network | radial basis function network,radial basis network,rbf network',
#      'Logical and relational learning | logical learning,relational learning',
#      'Inductive logic learning | inductive logic learning,inductive learning',
#      'Statistical relational learning | statistical relational learning,statistical learning',
#      'Association rule learning | association rule learning,association learning',
#      'Learning in probabilistic graphical models | learning graphical model',
#      'Maximum likelihood modeling | maximum likelihood',
#      'Maximum entropy modeling | maximum entropy',
#      'Maximum a posteriori modeling | maximum a posteriori',
#      'Latent variable models | latent variable',
#      'Bayesian network models | bayesian network,bayesian model',
#      'Naive bayes classifier | naive bayes classifier,na ve bayes classifier,naïve bayes classifier',
#      'Factorization methods |',
#      'Non-negative matrix factorization | non negative matrix factorization,non-negative matrix approximation, nmf , nnmf',
#      'Factor analysis |',
#      'Principal component analysis | principal component analysis, pca',
#      'Canonical correlation analysis |',
#      'Latent Dirichlet allocation |',
#      'Linear discriminant analysis |',
#      'Rule learning |',
#      'Instance-based learning | instance based learning,memory based learning',
#      'Bio-inspired approaches |',
#      'Artificial life |',
#      'Artificial immune system |',
#      'Evolvable hardware |',
#      'Genetic algorithms |',
#      'Genetic programming |',
#      'Evolutionary robotics |',
#      'Generative and developmental approaches | generative approach,developmental approach',
#      'Dynamic programming for Markov decision processes | Markov decision process, mdp',
#      'Multi-armed bandit algorithm | armed bandit',
#      'Value iteration |',
#      'Q-learning |',
#      'Policy iteration |',
#      'Temporal difference learning |',
#      'Approximate dynamic programming methods |',
#      'Spectral methods |',
#      'Feature engineering |',
#      'Feature extraction |',
#      'Feature projection |',
#      'Feature learning |',
#      'Feature selection |',
#      'Regularization |']],
#    'Modeling and simulation | modeling,simulation',
#    'Model development and analysis | model development,model analysis',
#    ['Modeling methodologies |',
#     'Model verification and validation | model verification,model validation',
#     'Uncertainty quantification |',
#     'Simulation types and techniques | simulation technique',
#     'Uncertainty quantification |',
#     'Quantum mechanic simulation |',
#     'Molecular simulation |',
#     'Rare-event simulation |',
#     'Discrete-event simulation |',
#     'Agent and discrete models | agent model,discrete model',
#     'Distributed simulation |',
#     'Continuous simulation |',
#     'Continuous models |',
#     'Real-time simulation |',
#     'Interactive simulation |',
#     'Multiscale systems |',
#     'Massively parallel and high-performance simulations | massively parallel simulation,high-performance simulation',
#     'Data assimilation |',
#     'Scientific visualization |',
#     'Visual analytics |',
#     'Simulation by animation |',
#     'Artificial life |'],
#    'Mathematical algorithms and methods | mathematical',
#    ['Symbolic and algebraic algorithms |',
#     'Combinatorial algorithms | combinatorial',
#     'Algebraic algorithms | algebraic',
#     'Nonalgebraic algorithms | nonalgebraic',
#     'Symbolic calculus algorithms | symbolic calculus',
#     'Exact arithmetic algorithms | exact arithmetic',
#     'Hybrid symbolic-numeric methods | hybrid symbolic-numeric',
#     'Discrete calculus algorithms | discrete calculus',
#     'Number theory algorithms | number theory',
#     'Equation and inequality solving algorithms | equation solving,inequality solving',
#     'Linear algebra algorithms | linear algebra',
#     'Theorem proving algorithms | theorem proving',
#     'Boolean algebra algorithms | boolean algebra',
#     ['Optimization algorithms |',
#      'Graph theory |',
#      'Trees |',
#      'Hypergraphs |',
#      'Random graphs |',
#      'Graph coloring |',
#      'Paths and connectivity problems | pathfinding,graph connect,graph search',
#      'Graph enumeration |',
#      'Matchings and factors | graph matching,graph factors',
#      'Spectra of graphs |',
#      'Extremal graph theory |',
#      'Matroids and greedoids | matroid,greedoid',
#      'Graph algorithms |',
#      'Approximation | graph approximation',
#      'Backpropagation |',
#      'Graph algorithms analysis |',
#      'Network flows | network flow,network graph',
#      'Sparsification and spanners | graph sparsification,graph spanner',
#      ['Shortest paths |', 'Dynamic graph algorithms |']],
#     'Probability and statistics | statistical analysis',
#     ['Probabilistic representations |',
#      ['Bayesian networks |',
#       'Markov networks |',
#       'Factor graphs |',
#       'Decision diagrams |',
#       'Equational models |',
#       'Causal networks |',
#       'Stochastic differential equations |',
#       'Autoregressive model |',
#       'Nonparametric representations |',
#       ['Kernel density estimators |',
#        'Spline models |',
#        'Bayesian nonparametric models |']],
#      'Probabilistic inference problems | probabilistic inference',
#      ['Maximum likelihood estimation |',
#       'Bayesian computation | bayesian computation,bayesian analysis',
#       'Computing most probable explanation |',
#       'Hypothesis testing and confidence interval computation | hypothesis testing,confidence interval computation',
#       'Density estimation |',
#       ['Quantile regression |', 'Max marginal computation |']],
#      'Probabilistic reasoning algorithms | probabilistic reasoning',
#      ['Variable elimination |',
#       'Loopy belief propagation |',
#       'Variational methods |',
#       'Expectation maximization |',
#       'Markov-chain Monte Carlo methods | markov chain monte carlo',
#       ['Gibbs sampling |',
#        'Metropolis-Hastings algorithm |',
#        'Simulated annealing |',
#        'Markov-chain Monte Carlo convergence measures | markov chain monte carlo convergence',
#        'Sequential Monte Carlo methods |'],
#       'Kalman filters and hidden Markov models | kalman filter,hidden markov model',
#       'Resampling methods |',
#       ['Bootstrapping |',
#        'Jackknifing | jackknif',
#        'Random number generation | random number generation, rng'],
#       'Probabilistic algorithms |',
#       'Statistical paradigms |',
#       'Queueing theory |',
#       'Contingency table analysis |',
#       'Regression analysis |',
#       ['Robust regression |',
#        'Linear regression |',
#        ['Bayesian regression |',
#         'Logistic Regression |',
#         'Lasso regression |',
#         'Poisson regression |',
#         'Binomial regression |'],
#        'Time series analysis |',
#        'Survival analysis |',
#        'Cox proportional hazards model | cox regression,cox proportional hazards',
#        'Renewal theory |',
#        'Statistical graphics |',
#        'Exploratory data analysis |'],
#       'Nonparametric statistics |',
#       'Distribution functions |'],
#      'Univariate statistics | univariate',
#      'Multivariate statistics | multivariate,multivariable',
#      'Mathematical software |',
#      'Solvers |',
#      'Statistical software |',
#      'Mathematical analysis |',
#      'Numerical analysis |',
#      'Computation of transforms | transformation',
#      'Computations in finite fields | finite field',
#      'Computations on matrices | matrix,matrices',
#      'Computations on polynomials | gröbner bases,polynomial',
#      ['Number-theoretic computations |',
#       'Interpolation |',
#       'Numerical differentiation |',
#       'Interval arithmetic |',
#       'Arbitrary-precision arithmetic |',
#       'Automatic differentiation |',
#       'Mesh generation |',
#       'Discretization |',
#       'Mathematical optimization |',
#       'Discrete optimization |',
#       ['Network optimization |',
#        'Optimization with randomized search heuristics | random optimization, randomized search heuristic',
#        ['Simulated annealing |',
#         'Evolutionary algorithms | evolutionary computation,evolutionary algorithm',
#         'Tabu search |',
#         'Randomized local search |',
#         'Hill climbing |',
#         'Beam search |'],
#        'Continuous optimization |',
#        'Dynamic programming |',
#        'Linear programming |',
#        'Semidefinite programming |',
#        'Convex optimization |',
#        'Quasiconvex programming and unimodality | quasiconvex programming,unimodality',
#        'Stochastic control and optimization | stochastic control, stochastic optimization',
#        'Quadratic programming |',
#        'Nonconvex optimization |',
#        'Bio-inspired optimization |',
#        'Mixed discrete-continuous optimization |',
#        'Submodular optimization and polymatroids | submodular optimization,polymatroids',
#        'Integer programming |']]]],
#    'Algorithmic game theory and mechanism design | game theory,mechanism design',
#    'Algorithmic game theory | game theory',
#    'Computation of equilibria | computation of equilibri,equilibria computation,equilibrium computation',
#    'Nash equilibria | nash equilibri',
#    'Quality of equilibria | Quality of equilibri,efficiency of equilibri',
#    'Algorithmic mechanism design | mechanism design',
#    'Social networks | social network,soial choice',
#    'Convergence and learning in games | convergence in game,learning in game',
#    'Market equilibria | market equilibri',
#    'Computational pricing and auctions | Computational pricing,computational auction',
#    ['Network games |',
#     'Network formation |',
#     'Computational advertising theory | computational advertising'],
#    'Information retrieval and data mining | information retrieval,data mining,big data,data science,data extraction',
#    'Data structures design and analysis | data analysis,data analytics',
#    ['Data compression |',
#     'Pattern matching |',
#     'Sorting and searching | data sorting,data searching',
#     'Predecessor queries |',
#     'Cell probe models and lower bounds | cell probe model,lower bounds',
#     'Database theory |',
#     ['Data exchange |',
#      'Data provenance |',
#      'Data modeling |',
#      'Database query languages |',
#      'Database constraints theory |',
#      'Database interoperability |',
#      'Data structures and algorithms for data management | data management',
#      'Database query processing and optimization | query processing,query optimization',
#      'Data integration |',
#      'Logic and databases |',
#      'Database privacy and security | database privacy, database security',
#      'Incomplete, inconsistent, and uncertain databases | incomplete database,inconsistent database,uncertain database'],
#     'Information retrieval query processing | query processing',
#     'Query representation |',
#     'Query intent |',
#     'Query log analysis |',
#     'Query suggestion |',
#     'Query reformulation |',
#     'Users and interactive retrieval | interactive retrieval',
#     'Personalization | personalized information retrieval',
#     'Task models |',
#     'Search interfaces |',
#     'Collaborative search |',
#     'Retrieval models and ranking | retrieval model,ranking',
#     'Rank aggregation |',
#     'Probabilistic retrieval models | probabilistic retrieval',
#     'Language models |',
#     'Similarity measures |',
#     'Learning to rank |',
#     'Combination, fusion and federated search | federated search,data fusion,data combin',
#     'Information retrieval diversity | retrieval diversity',
#     'Top-k retrieval in databases | top k retrieval',
#     'Novelty in information retrieval |',
#     'Retrieval tasks and goals | retrieval task,retrieval goal',
#     'Question answering |',
#     'Document filtering |',
#     'Recommender systems |',
#     'Information extraction |',
#     'Sentiment analysis |',
#     'Expert search |',
#     'Near-duplicate and plagiarism detection | near duplicate detection,plagiarism detection',
#     'Clustering | cluster',
#     'Classification | classifi',
#     'Summarization | text summar,document summar,data summar',
#     'Business intelligence |',
#     'Evaluation of retrieval results |',
#     'Test collections |',
#     'Relevance assessment |',
#     'Retrieval effectiveness |',
#     'Retrieval efficiency |',
#     'Presentation of retrieval results |',
#     'Search engine architectures and scalability | search engine architecture,search engine scalability',
#     'Search engine indexing |',
#     'Search index compression |',
#     'Distributed retrieval |',
#     'Peer-to-peer retrieval |',
#     'Retrieval on mobile devices |',
#     'Adversarial retrieval |',
#     'Link and co-citation analysis | link analysis,citation analysis',
#     'Searching with auxiliary databases | auxiliary database',
#     'Specialized information retrieval |',
#     'Structured and multilingual text search |',
#     ['Structured text search |',
#      'Mathematics retrieval |',
#      'Chemical and biochemical retrieval | chemical retrieval',
#      'Multilingual and cross-lingual retrieval | lingual retrieval'],
#     'Multimedia and multimodal retrieval | multimedia retrieval,multimodal retrieval',
#     'Image search | image search,image retrieval',
#     'Video search | video search,video retrieval',
#     'Speech and audio search | speech search,audio search,speech retrieval,audio retrieval',
#     'Music retrieval | music retrieval,music search',
#     'Environment-specific retrieval |',
#     ['Enterprise search |', 'Desktop search |'],
#     'Web mining | web mining,web retrieval',
#     ['Site wrapping |',
#      'Data extraction and integration | web data extraction,web data integration',
#      ['Deep web |',
#       'Surfacing |',
#       'Search results deduplication |',
#       'Web log analysis |',
#       'Traffic analysis |',
#       'Web crawling |',
#       'Web indexing |'],
#      'Page and site ranking | page ranking,site ranking',
#      'Spam detection |'],
#     'Human-centered computing |',
#     'Cognitive computing |',
#     'Affective computing |',
#     'Human computer interaction |  hci ,human machine interaction,human machine interface,human computer interface',
#     'Interaction paradigms |',
#     'Hypertext and hypermedia | hypertext,hypermedia',
#     'Mixed and augmented reality | mixed reality,augmented reality',
#     ['Command line interfaces |',
#      'Graphical user interfaces | graphical user interface, gui',
#      'Virtual reality |',
#      'Virtual assistants |',
#      'Chatbots |',
#      'Question answering systems | question answering',
#      'Decision support systems | decision support,decision model',
#      ['Expert systems |'],
#      'Web-based interaction | web based communication,web based interaction,online communication',
#      'Digital assistants |',
#      'Natural language interfaces |',
#      'Collaborative interaction |',
#      'Interaction techniques |',
#      'Auditory feedback |',
#      'Text input |',
#      'Pointing |',
#      'Gestural input | gestural input,gesture input,gesture recognition'],
#     'Ubiquitous and mobile computing |',
#     'Ubiquitous and mobile computing theory, concepts and paradigms |',
#     'Ubiquitous computing | ubiquitous,pervasive,mobile computing',
#     'Mobile computing | mobile computing,mobile app, smartphone app',
#     ['Ambient intelligence |',
#      'Internet-of-things |',
#      'Location based services |'],
#     'Smart applications | smart',
#     ['Smart city |', 'Smart home |', 'Smart device |', 'Wearables |']],
#    'Embedded and cyber-physical systems | embedded,cyber physical',
#    'Sensors and actuators | sensor,actuator',
#    ['Sensor data |',
#     'Sensor networks | sensor network,sensor system',
#     ['Sensor fusion |'],
#     'Robotics | robot',
#     'Robotic components |',
#     'Robotic control |',
#     ['Evolutionary robotics |'],
#     'Robotic autonomy | autonomous robot,robotic autonomy',
#     'Brain-computer interfaces | brain computer interface, bci',
#     'Neuroprosthetics |',
#     'Robot-assisted surgery | robotic assisted,robot assisted',
#     'Autonomous vehicles | autonomous vehicle,self driving',
#     'Humanoid robots |',
#     'System on a chip |',
#     'Embedded systems |',
#     'Firmware |',
#     'Embedded hardware |',
#     'Embedded software |',
#     'Healthcare and medicine specific applications |',
#     'Computational chemistry |',
#     'Computational biology |',
#     'Molecular sequence analysis |',
#     'Molecular evolution |',
#     'Biological networks |',
#     'Molecular structural biology |',
#     'Genetics and Genomics | genetic analysis,gene analysis,genome analysis,genetic model,genome interpretation',
#     'Proteomics | proteomic analysis,proteomic profiling,proteome profiling',
#     ['Pathway analysis |',
#      'Gene ontology analysis | gene ontology',
#      'Gene set enrichment analysis | enrichment analysis,gene ontology term enrichment',
#      'Gene expression profiling | gene profiling,genetic profiling,expression profiling,gene expression analysis,dna seq',
#      ['Microarray analysis |',
#       'Transcriptomics | transcriptomics,transcriptome profiling,transcriptomic profiling,transcriptome sequencing,transcriptomic analysis,transcriptome analysis',
#       'RNA sequencing |  rna seq, rna analysis]',
#       'miRNA sequencing | mirna seq,mirna analysis]',
#       'Whole genome sequencing | genome sequencing',
#       'Exome sequencing |',
#       'High-throughput methods | high throughput',
#       ['Long-read sequencing |', 'Short-read sequencing |']],
#      'Gene prediction | gene prediction,genetic prediction',
#      'Polygenic score | polygenic score,polygenic risk score,polygenic risk prediction',
#      'Genotype-to-phenotype prediction | phenotype prediction',
#      'Phenotype-to-genotype mapping | genotype mapping',
#      'DNA annotation | dna annotation, genome annotation'],
#     'Systems biology |',
#     'Consumer health |',
#     'Health care information systems |',
#     'Health informatics |',
#     'Bioinformatics |',
#     'Bioengineering |',
#     'Metabolomics and metabonomics | metabolomics,metabonomic']],
#   'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#   ['Natural language processing | natural language processing, nlp',
#    ['Syntactic analysis |',
#     'Grammar induction | grammar induction,grammar learning',
#     ['Stemming |',
#      'Lemmatization |',
#      'Morphological segmentation |',
#      'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#      ['Natural language processing | natural language processing, nlp',
#       ['Syntactic analysis |',
#        'Grammar induction | grammar induction,grammar learning',
#        ['Stemming |',
#         'Lemmatization |',
#         'Morphological segmentation |',
#         'Part-of-speech tagging | part of speech tagging,pos tagging',
#         'Syntactic Parsing |',
#         'Sentence boundary disambiguation | sentence boundary disambiguation,sentence breaking',
#         'Word segmentation |',
#         'Terminology extraction |',
#         'Semantic analysis |',
#         'Lexical semantics |',
#         'Distributional semantics |',
#         'Machine Translation |',
#         'Named entity recognition |  ner ,entity recognition',
#         'Natural language generation | natural language generation, nlg',
#         'Question answering |',
#         'Sentiment analysis |',
#         'Topic segmentation |',
#         'Word sense disambiguation |',
#         'Ontology learning |',
#         'Word embedding |',
#         'Bag-of-words model | bag of words',
#         'Context recognition |',
#         'Discourse, dialogue and pragmatics |',
#         'Text summarization |',
#         'Text mining |',
#         'Text classification |',
#         'Discourse analysis |'],
#        'Speech recognition |'],
#       'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#       ['Natural language processing | natural language processing, nlp',
#        ['Syntactic analysis |',
#         'Grammar induction | grammar induction,grammar learning',
#         ['Stemming |',
#          'Lemmatization |',
#          'Morphological segmentation |',
#          'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#          ['Natural language processing | natural language processing, nlp',
#           ['Syntactic analysis |',
#            'Grammar induction | grammar induction,grammar learning',
#            ['Stemming |',
#             'Lemmatization |',
#             'Morphological segmentation |',
#             'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#             ['Natural language processing | natural language processing, nlp',
#              ['Syntactic analysis |',
#               'Grammar induction | grammar induction,grammar learning',
#               ['Stemming |',
#                'Lemmatization |',
#                'Morphological segmentation |',
#                'Artificial intelligence | artificial intelligence, ai ,computational intelligence,algorithm,autonomous,automated,automatic,computer aided',
#                ['Natural language processing | natural language processing, nlp',
#                 ['Syntactic analysis |',
#                  'Grammar induction | grammar induction,grammar learning',
#                  ['Stemming |',
#                   'Lemmatization |',
#                   'Morphological segmentation |',
#                   'Part-of-speech tagging | part of speech tagging,pos tagging',
#                   'Syntactic Parsing |',
#                   'Sentence boundary disambiguation | sentence boundary disambiguation,sentence breaking',
#                   'Word segmentation |',
#                   'Terminology extraction |',
#                   'Semantic analysis |',
#                   'Lexical semantics |',
#                   'Distributional semantics |',
#                   'Machine Translation |',
#                   'Named entity recognition |  ner ,entity recognition',
#                   'Natural language generation | natural language generation, nlg',
#                   'Question answering |',
#                   'Sentiment analysis |',
#                   'Topic segmentation |',
#                   'Word sense disambiguation |',
#                   'Ontology learning |',
#                   'Word embedding |',
#                   'Bag-of-words model | bag of words',
#                   'Context recognition |',
#                   'Discourse, dialogue and pragmatics |',
#                   'Text summarization |',
#                   'Text mining |',
#                   'Text classification |',
#                   'Discourse analysis |'],
#                  'Speech recognition |'],
#                 'Logic, knowledge representation and reasoning | rule based,logic,reasoning,knowledge representation',
#                 'Rule-based reasoning | rule based',
#                 ['Hand-crafted rules |',
#                  'Proof theory |',
#                  'Modal and temporal logics | modal logic,temporal logic',
#                  'Automated reasoning |',
#                  'Constraint and logic programming | constraint programming,logic programming',
#                  'Constructive mathematics |',
#                  'Description logics |',
#                  'Equational logic and rewriting | equational logic',
#                  'Finite Model Theory |',
#                  'Higher order logic |',
#                  'Linear logic |',
#                  'Programming logic |',
#                  'Verification by model checking |',
#                  'Type theory |',
#                  'Hoare logic |',
#                  'Separation logic |',
#                  'Semantic networks |',
#                  'Nonmonotonic, default reasoning and belief revision | nonmonotonic reasoning,default reasoning,belief revision',
#                  'Probabilistic reasoning |',
#                  'Vagueness and fuzzy logic | fuzzy logic',
#                  'Causal reasoning |',
#                  'Temporal reasoning |',
#                  'Cognitive robotics |',
#                  'Ontology engineering |',
#                  'Logic programming and answer set programming | logic programming,answer set programming',
#                  'Spatial and physical reasoning | spatial reasoning,physical reasoning',
#                  'Case-based reasoning |',
#                  'Constraint-based reasoning |',
#                  'Propositional logic | propositional logic,statement logic,sentential logic',
#                  'First-order logic | first order logic,predicate logic,quantificational logic',
#                  'Abductive reasoning |',
#                  'Analogical reasoning |'],
#                 'Searching, planning and scheduling | search algorithm,automated planning,automated scheduling',
#                 'Planning for deterministic actions | deterministic planning',
#                 ['State-space search |',
#                  'Forward search |',
#                  'Backward search |',
#                  'Heuristic search algorithms | heuristic search',
#                  'Planning under uncertainty | non deterministic planning',
#                  'Systematic nonlinear planning | systematic nonlinear planning, snlp',
#                  'Multi-agent planning |',
#                  'Robotic planning |',
#                  ['Evolutionary robotics |'],
#                  'Heuristic function construction | heuristic function',
#                  'Discrete space search |',
#                  'Continuous space search |',
#                  'Randomized search |',
#                  'Tree search  |',
#                  'Distributed artificial intelligence |',
#                  'Multi-agent systems |',
#                  'Intelligent agents |',
#                  'Mobile agents |',
#                  'Cooperation and coordination |',
#                  'Parallel and distributed algorithms | parallel algorithm,distributed algorithm',
#                  ['MapReduce algorithms |',
#                   'Self-organization |',
#                   'Shared memory algorithms |',
#                   'Vector and streaming algorithms | vector algorithm,streaming algorithm',
#                   'Massively parallel algorithms |',
#                   'Swarm intelligence |',
#                   'Ant colony optimization |',
#                   'Particle swarm optimization |']],
#                 'Computer vision | computer vision,machine perception',
#                 ['Image recognition |',
#                  'Biometrics |',
#                  'Scene understanding |',
#                  'Activity recognition and understanding | activity recognition,activity understanding',
#                  ['Gesture recognition |',
#                   ['Motion recognition |',
#                    'Facial recognition  |',
#                    'Emotion detection |'],
#                   'Video summarization |'],
#                  'Visual content-based indexing and retrieval | visual content based indexing,visual content based retrieval',
#                  'Visual inspection |',
#                  'Vision for robotics | robotic vision,robot vision,robot perception',
#                  'Scene anomaly detection |',
#                  'Interest point and salient region detections | interest point detection,salient region detection',
#                  'Image segmentation | image segmentation,automated segmentation',
#                  'Image analysis | image analysis,image processing,image analytics',
#                  'Video segmentation |',
#                  'Shape inference |',
#                  'Object detection and recognition | object detection,object identification,object recognition,obstacle recognition',
#                  'Spatial recognition |',
#                  'Tracking | visual tracking,object tracking',
#                  'Reconstruction | image reconstruction,3d reconstruction',
#                  'Matching | image matching,feature matching,template matching'],
#                 'Machine learning | machine learning, ml ,learning algorithm,prediction algorithm,prediction model,knowledge aquisition,knowledge extraction',
#                 ['Learning paradigms |',
#                  'Supervised learning |  supervised learning,imitation learning',
#                  ['Learning to rank | learning to rank,machine learned ranking',
#                   'Supervised learning by classification | classification, classifier',
#                   ['Multi-class classification |',
#                    'Regression |',
#                    'Structured outputs |',
#                    'Cost-sensitive learning |'],
#                   'Unsupervised learning | unsupervised learning,self learning',
#                   'Cluster analysis | cluster analysis,clustering',
#                   ['Anomaly detection |',
#                    'Mixture modeling | mixture model,mixed model',
#                    'Topic modeling |',
#                    'Source separation |',
#                    'Motif discovery |',
#                    'Dimensionality reduction and manifold learning | dimensionality reduction,manifold learning',
#                    'Semi-supervised learning |',
#                    'Reinforcement learning |',
#                    'Sequential decision making |',
#                    'Inverse reinforcement learning |',
#                    'Apprenticeship learning |',
#                    'Multi-agent reinforcement learning |',
#                    'Adversarial learning |',
#                    'Multi-task learning |',
#                    'Transfer learning |',
#                    'Lifelong machine learning |',
#                    'Learning under covariate shift |',
#                    'Deep learning |']],
#                  'Machine learning approaches and algorithms | learning algorithm,learning model,learning approach',
#                  'Classification and regression trees | classification algorithm,regression tree',
#                  ['Decision trees |',
#                   'Ensemble methods | ensemble',
#                   ['Boosting |',
#                    'Bagging |',
#                    'Random forest |',
#                    'Gradient boosting |',
#                    'k-nearest-neighbor algorithm | k nearest neighbor, k nn'],
#                   'Perceptron algorithm | perceptron',
#                   'Clustering algorithms |',
#                   'K-means |  k means',
#                   'Density-based algorithms |',
#                   ['DBSCAN |',
#                    'Hierarchical clustering |',
#                    'Agglomerative hierarchical clustering | agglomerative hierarchical clustering,agglomerative clustering',
#                    'Divisive hierarchical clustering | divisive hierarchical clustering,divisive clustering'],
#                   'Kernel methods |',
#                   'Support vector machines | support vector, svm',
#                   'Gaussian processes |',
#                   'Gaussian naive bayes  | gaussian naive bayes,gaussian na ve bayes,gaussian naïve bayes',
#                   'Artificial neural networks | neural network, nn , ann',
#                   'Autoencoder |',
#                   'Multilayer perceptron |',
#                   'Deep neural network  | deep neural network, dnn',
#                   'Deep belief network |',
#                   'Recurrent neural network | recurrent neural network, rnn',
#                   ['Long short term memory network | long short term memory network, lstm',
#                    'Generative adversarial network | generative adversarial network, gan',
#                    'Convolutional neural network | convolutional neural network, cnn',
#                    'Self-organizing map | self organizing map, som'],
#                   'Feed-forward neural network | feed forward neural network,constructive neural network',
#                   'Spiking neural network | spiking neural network, snn',
#                   'Radial basis function network | radial basis function network,radial basis network,rbf network',
#                   'Logical and relational learning | logical learning,relational learning',
#                   'Inductive logic learning | inductive logic learning,inductive learning',
#                   'Statistical relational learning | statistical relational learning,statistical learning',
#                   'Association rule learning | association rule learning,association learning',
#                   'Learning in probabilistic graphical models | learning graphical model',
#                   'Maximum likelihood modeling | maximum likelihood',
#                   'Maximum entropy modeling | maximum entropy',
#                   'Maximum a posteriori modeling | maximum a posteriori',
#                   'Latent variable models | latent variable',
#                   'Bayesian network models | bayesian network,bayesian model',
#                   'Naive bayes classifier | naive bayes classifier,na ve bayes classifier,naïve bayes classifier',
#                   'Factorization methods |',
#                   'Non-negative matrix factorization | non negative matrix factorization,non-negative matrix approximation, nmf , nnmf',
#                   'Factor analysis |',
#                   'Principal component analysis | principal component analysis, pca',
#                   'Canonical correlation analysis |',
#                   'Latent Dirichlet allocation |',
#                   'Linear discriminant analysis |',
#                   'Rule learning |',
#                   'Instance-based learning | instance based learning,memory based learning',
#                   'Bio-inspired approaches |',
#                   'Artificial life |',
#                   'Artificial immune system |',
#                   'Evolvable hardware |',
#                   'Genetic algorithms |',
#                   'Genetic programming |',
#                   'Evolutionary robotics |',
#                   'Generative and developmental approaches | generative approach,developmental approach',
#                   'Dynamic programming for Markov decision processes | Markov decision process, mdp',
#                   'Multi-armed bandit algorithm | armed bandit',
#                   'Value iteration |',
#                   'Q-learning |',
#                   'Policy iteration |',
#                   'Temporal difference learning |',
#                   'Approximate dynamic programming methods |',
#                   'Spectral methods |',
#                   'Feature engineering |',
#                   'Feature extraction |',
#                   'Feature projection |',
#                   'Feature learning |',
#                   'Feature selection |',
#                   'Regularization |']],
#                 'Modeling and simulation | modeling,simulation',
#                 'Model development and analysis | model development,model analysis',
#                 ['Modeling methodologies |',
#                  'Model verification and validation | model verification,model validation',
#                  'Uncertainty quantification |',
#                  'Simulation types and techniques | simulation technique',
#                  'Uncertainty quantification |',
#                  'Quantum mechanic simulation |',
#                  'Molecular simulation |',
#                  'Rare-event simulation |',
#                  'Discrete-event simulation |',
#                  'Agent and discrete models | agent model,discrete model',
#                  'Distributed simulation |',
#                  'Continuous simulation |',
#                  'Continuous models |',
#                  'Real-time simulation |',
#                  'Interactive simulation |',
#                  'Multiscale systems |',
#                  'Massively parallel and high-performance simulations | massively parallel simulation,high-performance simulation',
#                  'Data assimilation |',
#                  'Scientific visualization |',
#                  'Visual analytics |',
#                  'Simulation by animation |',
#                  'Artificial life |'],
#                 'Mathematical algorithms and methods | mathematical',
#                 ['Symbolic and algebraic algorithms |',
#                  'Combinatorial algorithms | combinatorial',
#                  'Algebraic algorithms | algebraic',
#                  'Nonalgebraic algorithms | nonalgebraic',
#                  'Symbolic calculus algorithms | symbolic calculus',
#                  'Exact arithmetic algorithms | exact arithmetic',
#                  'Hybrid symbolic-numeric methods | hybrid symbolic-numeric',
#                  'Discrete calculus algorithms | discrete calculus',
#                  'Number theory algorithms | number theory',
#                  'Equation and inequality solving algorithms | equation solving,inequality solving',
#                  'Linear algebra algorithms | linear algebra',
#                  'Theorem proving algorithms | theorem proving',
#                  'Boolean algebra algorithms | boolean algebra',
#                  ['Optimization algorithms |',
#                   'Graph theory |',
#                   'Trees |',
#                   'Hypergraphs |',
#                   'Random graphs |',
#                   'Graph coloring |',
#                   'Paths and connectivity problems | pathfinding,graph connect,graph search',
#                   'Graph enumeration |',
#                   'Matchings and factors | graph matching,graph factors',
#                   'Spectra of graphs |',
#                   'Extremal graph theory |',
#                   'Matroids and greedoids | matroid,greedoid',
#                   'Graph algorithms |',
#                   'Approximation | graph approximation',
#                   'Backpropagation |',
#                   'Graph algorithms analysis |',
#                   'Network flows | network flow,network graph',
#                   'Sparsification and spanners | graph sparsification,graph spanner',
#                   ['Shortest paths |', 'Dynamic graph algorithms |']],
#                  'Probability and statistics | statistical analysis',
#                  ['Probabilistic representations |',
#                   ['Bayesian networks |',
#                    'Markov networks |',
#                    'Factor graphs |',
#                    'Decision diagrams |',
#                    'Equational models |',
#                    'Causal networks |',
#                    'Stochastic differential equations |',
#                    'Autoregressive model |',
#                    'Nonparametric representations |',
#                    ['Kernel density estimators |',
#                     'Spline models |',
#                     'Bayesian nonparametric models |']],
#                   'Probabilistic inference problems | probabilistic inference',
#                   ['Maximum likelihood estimation |',
#                    'Bayesian computation | bayesian computation,bayesian analysis',
#                    'Computing most probable explanation |',
#                    'Hypothesis testing and confidence interval computation | hypothesis testing,confidence interval computation',
#                    'Density estimation |',
#                    ['Quantile regression |', 'Max marginal computation |']],
#                   'Probabilistic reasoning algorithms | probabilistic reasoning',
#                   ['Variable elimination |',
#                    'Loopy belief propagation |',
#                    'Variational methods |',
#                    'Expectation maximization |',
#                    'Markov-chain Monte Carlo methods | markov chain monte carlo',
#                    ['Gibbs sampling |',
#                     'Metropolis-Hastings algorithm |',
#                     'Simulated annealing |',
# ...
#      'Evolutionary robotics |'],
#     'Generative and developmental approaches | generative approach,developmental approach',
#     'Dynamic programming for Markov decision processes | Markov decision process, mdp',
#     'Multi-armed bandit algorithm | armed bandit',
#     ['Value iteration |',
#      'Q-learning |',
#      'Policy iteration |',
#      'Temporal difference learning |',
#      'Approximate dynamic programming methods |'],
#     'Spectral methods |',
#     'Feature engineering |',
#     ['Feature extraction |',
#      'Feature projection |',
#      'Feature learning |',
#      'Feature selection |'],
#     'Regularization |']],
#   'Modeling and simulation | modeling,simulation',
#   ['Model development and analysis | model development,model analysis',
#    ['Modeling methodologies |'],
#    'Model verification and validation | model verification,model validation',
#    ['Uncertainty quantification |'],
#    'Simulation types and techniques | simulation technique',
#    ['Uncertainty quantification |',
#     'Quantum mechanic simulation |',
#     'Molecular simulation |',
#     'Rare-event simulation |',
#     'Discrete-event simulation |'],
#    'Agent and discrete models | agent model,discrete model',
#    ['Distributed simulation |',
#     'Continuous simulation |',
#     'Continuous models |',
#     'Real-time simulation |',
#     'Interactive simulation |',
#     'Multiscale systems |'],
#    'Massively parallel and high-performance simulations | massively parallel simulation,high-performance simulation',
#    ['Data assimilation |',
#     'Scientific visualization |',
#     'Visual analytics |',
#     'Simulation by animation |',
#     'Artificial life |']],
#   'Mathematical algorithms and methods | mathematical',
#   ['Symbolic and algebraic algorithms |',
#    'Combinatorial algorithms | combinatorial',
#    'Algebraic algorithms | algebraic',
#    'Nonalgebraic algorithms | nonalgebraic',
#    'Symbolic calculus algorithms | symbolic calculus',
#    'Exact arithmetic algorithms | exact arithmetic',
#    'Hybrid symbolic-numeric methods | hybrid symbolic-numeric',
#    'Discrete calculus algorithms | discrete calculus',
#    'Number theory algorithms | number theory',
#    'Equation and inequality solving algorithms | equation solving,inequality solving',
#    'Linear algebra algorithms | linear algebra',
#    'Theorem proving algorithms | theorem proving',
#    'Boolean algebra algorithms | boolean algebra',
#    ['Optimization algorithms |'],
#    'Graph theory |',
#    ['Trees |', 'Hypergraphs |', 'Random graphs |', 'Graph coloring |'],
#    'Paths and connectivity problems | pathfinding,graph connect,graph search',
#    ['Graph enumeration |'],
#    'Matchings and factors | graph matching,graph factors',
#    ['Spectra of graphs |', 'Extremal graph theory |'],
#    'Matroids and greedoids | matroid,greedoid',
#    ['Graph algorithms |'],
#    'Approximation | graph approximation',
#    ['Backpropagation |',
#     'Graph algorithms analysis |',
#     'Network flows | network flow,network graph',
#     'Sparsification and spanners | graph sparsification,graph spanner',
#     ['Shortest paths |', 'Dynamic graph algorithms |']]],
#   'Probability and statistics | statistical analysis',
#   ['Probabilistic representations |',
#    ['Bayesian networks |',
#     'Markov networks |',
#     'Factor graphs |',
#     'Decision diagrams |',
#     'Equational models |',
#     'Causal networks |',
#     'Stochastic differential equations |',
#     'Autoregressive model |',
#     'Nonparametric representations |',
#     ['Kernel density estimators |',
#      'Spline models |',
#      'Bayesian nonparametric models |']]],
#   'Probabilistic inference problems | probabilistic inference',
#   ['Maximum likelihood estimation |'],
#   'Bayesian computation | bayesian computation,bayesian analysis',
#   ['Computing most probable explanation |'],
#   'Hypothesis testing and confidence interval computation | hypothesis testing,confidence interval computation',
#   ['Density estimation |',
#    ['Quantile regression |'],
#    'Max marginal computation |'],
#   'Probabilistic reasoning algorithms | probabilistic reasoning',
#   ['Variable elimination |',
#    'Loopy belief propagation |',
#    'Variational methods |',
#    'Expectation maximization |',
#    'Markov-chain Monte Carlo methods | markov chain monte carlo',
#    ['Gibbs sampling |',
#     'Metropolis-Hastings algorithm |',
#     'Simulated annealing |'],
#    'Markov-chain Monte Carlo convergence measures | markov chain monte carlo convergence',
#    'Sequential Monte Carlo methods |'],
#   'Kalman filters and hidden Markov models | kalman filter,hidden markov model',
#   ['Resampling methods |',
#    ['Bootstrapping |'],
#    'Jackknifing | jackknif',
#    'Random number generation | random number generation, rng'],
#   'Probabilistic algorithms |',
#   ['Statistical paradigms |',
#    ['Queueing theory |',
#     'Contingency table analysis |',
#     'Regression analysis |',
#     ['Robust regression |',
#      'Linear regression |',
#      ['Bayesian regression |'],
#      'Logistic Regression |',
#      'Lasso regression |',
#      'Poisson regression |',
#      'Binomial regression |'],
#     'Time series analysis |',
#     'Survival analysis |',
#     'Cox proportional hazards model | cox regression,cox proportional hazards',
#     'Renewal theory |',
#     'Statistical graphics |',
#     'Exploratory data analysis |'],
#    'Nonparametric statistics |',
#    'Distribution functions |'],
#   'Univariate statistics | univariate',
#   ['Multivariate statistics | multivariate,multivariable',
#    'Mathematical software |',
#    ['Solvers |', 'Statistical software |'],
#    'Mathematical analysis |',
#    ['Numerical analysis |',
#     'Computation of transforms | transformation',
#     'Computations in finite fields | finite field',
#     'Computations on matrices | matrix,matrices',
#     'Computations on polynomials | gröbner bases,polynomial',
#     ['Number-theoretic computations |',
#      'Interpolation |',
#      'Numerical differentiation |',
#      'Interval arithmetic |',
#      'Arbitrary-precision arithmetic |',
#      'Automatic differentiation |',
#      'Mesh generation |',
#      'Discretization |'],
#     'Mathematical optimization |',
#     ['Discrete optimization |',
#      ['Network optimization |'],
#      'Optimization with randomized search heuristics | random optimization, randomized search heuristic',
#      ['Simulated annealing |'],
#      'Evolutionary algorithms | evolutionary computation,evolutionary algorithm',
#      ['Tabu search |',
#       'Randomized local search |',
#       'Hill climbing |',
#       'Beam search |'],
#      'Continuous optimization |',
#      ['Dynamic programming |',
#       'Linear programming |',
#       'Semidefinite programming |',
#       'Convex optimization |'],
#      'Quasiconvex programming and unimodality | quasiconvex programming,unimodality',
#      'Stochastic control and optimization | stochastic control, stochastic optimization',
#      ['Quadratic programming |',
#       'Nonconvex optimization |',
#       'Bio-inspired optimization |'],
#      'Mixed discrete-continuous optimization |',
#      'Submodular optimization and polymatroids | submodular optimization,polymatroids',
#      ['Integer programming |']]]],
#   'Algorithmic game theory and mechanism design | game theory,mechanism design',
#   ['Algorithmic game theory | game theory',
#    'Computation of equilibria | computation of equilibri,equilibria computation,equilibrium computation',
#    'Nash equilibria | nash equilibri',
#    'Quality of equilibria | Quality of equilibri,efficiency of equilibri',
#    'Algorithmic mechanism design | mechanism design',
#    'Social networks | social network,soial choice',
#    'Convergence and learning in games | convergence in game,learning in game',
#    'Market equilibria | market equilibri',
#    'Computational pricing and auctions | Computational pricing,computational auction',
#    ['Network games |', 'Network formation |'],
#    'Computational advertising theory | computational advertising'],
#   'Information retrieval and data mining | information retrieval,data mining,big data,data science,data extraction',
#   ['Data structures design and analysis | data analysis,data analytics',
#    ['Data compression |', 'Pattern matching |'],
#    'Sorting and searching | data sorting,data searching',
#    ['Predecessor queries |'],
#    'Cell probe models and lower bounds | cell probe model,lower bounds',
#    ['Database theory |',
#     ['Data exchange |',
#      'Data provenance |',
#      'Data modeling |',
#      'Database query languages |',
#      'Database constraints theory |',
#      'Database interoperability |'],
#     'Data structures and algorithms for data management | data management',
#     'Database query processing and optimization | query processing,query optimization',
#     ['Data integration |', 'Logic and databases |'],
#     'Database privacy and security | database privacy, database security',
#     'Incomplete, inconsistent, and uncertain databases | incomplete database,inconsistent database,uncertain database'],
#    'Information retrieval query processing | query processing',
#    ['Query representation |',
#     'Query intent |',
#     'Query log analysis |',
#     'Query suggestion |',
#     'Query reformulation |'],
#    'Users and interactive retrieval | interactive retrieval',
#    ['Personalization | personalized information retrieval',
#     ['Task models |', 'Search interfaces |', 'Collaborative search |']],
#    'Retrieval models and ranking | retrieval model,ranking',
#    ['Rank aggregation |'],
#    'Probabilistic retrieval models | probabilistic retrieval',
#    ['Language models |', 'Similarity measures |', 'Learning to rank |'],
#    'Combination, fusion and federated search | federated search,data fusion,data combin',
#    ['Information retrieval diversity | retrieval diversity',
#     'Top-k retrieval in databases | top k retrieval',
#     ['Novelty in information retrieval |']],
#    'Retrieval tasks and goals | retrieval task,retrieval goal',
#    ['Question answering |',
#     'Document filtering |',
#     'Recommender systems |',
#     'Information extraction |',
#     'Sentiment analysis |',
#     'Expert search |'],
#    'Near-duplicate and plagiarism detection | near duplicate detection,plagiarism detection',
#    ['Clustering | cluster',
#     'Classification | classifi',
#     'Summarization | text summar,document summar,data summar',
#     ['Business intelligence |'],
#     'Evaluation of retrieval results |',
#     ['Test collections |',
#      'Relevance assessment |',
#      'Retrieval effectiveness |',
#      'Retrieval efficiency |',
#      'Presentation of retrieval results |']],
#    'Search engine architectures and scalability | search engine architecture,search engine scalability',
#    ['Search engine indexing |',
#     'Search index compression |',
#     'Distributed retrieval |',
#     'Peer-to-peer retrieval |',
#     'Retrieval on mobile devices |',
#     'Adversarial retrieval |'],
#    'Link and co-citation analysis | link analysis,citation analysis',
#    ['Searching with auxiliary databases | auxiliary database',
#     'Specialized information retrieval |',
#     ['Structured and multilingual text search |',
#      ['Structured text search |', 'Mathematics retrieval |'],
#      'Chemical and biochemical retrieval | chemical retrieval',
#      'Multilingual and cross-lingual retrieval | lingual retrieval'],
#     'Multimedia and multimodal retrieval | multimedia retrieval,multimodal retrieval',
#     ['Image search | image search,image retrieval',
#      'Video search | video search,video retrieval',
#      'Speech and audio search | speech search,audio search,speech retrieval,audio retrieval',
#      'Music retrieval | music retrieval,music search',
#      'Environment-specific retrieval |',
#      ['Enterprise search |', 'Desktop search |']],
#     'Web mining | web mining,web retrieval',
#     ['Site wrapping |'],
#     'Data extraction and integration | web data extraction,web data integration',
#     ['Deep web |', 'Surfacing |', 'Search results deduplication |'],
#     'Web log analysis |',
#     ['Traffic analysis |', 'Web crawling |', 'Web indexing |'],
#     'Page and site ranking | page ranking,site ranking',
#     ['Spam detection |']],
#    'Human-centered computing |',
#    ['Cognitive computing |', 'Affective computing |'],
#    'Human computer interaction |  hci ,human machine interaction,human machine interface,human computer interface',
#    ['Interaction paradigms |',
#     'Hypertext and hypermedia | hypertext,hypermedia',
#     'Mixed and augmented reality | mixed reality,augmented reality',
#     ['Command line interfaces |',
#      'Graphical user interfaces | graphical user interface, gui',
#      'Virtual reality |',
#      'Virtual assistants |',
#      'Chatbots |'],
#     'Question answering systems | question answering',
#     'Decision support systems | decision support,decision model',
#     ['Expert systems |'],
#     'Web-based interaction | web based communication,web based interaction,online communication',
#     ['Digital assistants |',
#      'Natural language interfaces |',
#      'Collaborative interaction |'],
#     'Interaction techniques |',
#     ['Auditory feedback |', 'Text input |', 'Pointing |'],
#     'Gestural input | gestural input,gesture input,gesture recognition'],
#    'Ubiquitous and mobile computing |',
#    ['Ubiquitous and mobile computing theory, concepts and paradigms |',
#     'Ubiquitous computing | ubiquitous,pervasive,mobile computing',
#     'Mobile computing | mobile computing,mobile app, smartphone app',
#     ['Ambient intelligence |',
#      'Internet-of-things |',
#      'Location based services |']],
#    'Smart applications | smart',
#    ['Smart city |', 'Smart home |', 'Smart device |', 'Wearables |']],
#   'Embedded and cyber-physical systems | embedded,cyber physical',
#   ['Sensors and actuators | sensor,actuator',
#    ['Sensor data |'],
#    'Sensor networks | sensor network,sensor system',
#    ['Sensor fusion |'],
#    'Robotics | robot',
#    ['Robotic components |', 'Robotic control |', ['Evolutionary robotics |']],
#    'Robotic autonomy | autonomous robot,robotic autonomy',
#    ['Brain-computer interfaces | brain computer interface, bci',
#     'Neuroprosthetics |'],
#    'Robot-assisted surgery | robotic assisted,robot assisted',
#    ['Autonomous vehicles | autonomous vehicle,self driving',
#     ['Humanoid robots |'],
#     'System on a chip |',
#     'Embedded systems |',
#     ['Firmware |', 'Embedded hardware |', 'Embedded software |']],
#    'Healthcare and medicine specific applications |',
#    ['Computational chemistry |',
#     'Computational biology |',
#     ['Molecular sequence analysis |',
#      'Molecular evolution |',
#      'Biological networks |',
#      'Molecular structural biology |'],
#     'Genetics and Genomics | genetic analysis,gene analysis,genome analysis,genetic model,genome interpretation',
#     ['Proteomics | proteomic analysis,proteomic profiling,proteome profiling',
#      ['Pathway analysis |'],
#      'Gene ontology analysis | gene ontology',
#      ['Gene set enrichment analysis | enrichment analysis,gene ontology term enrichment'],
#      'Gene expression profiling | gene profiling,genetic profiling,expression profiling,gene expression analysis,dna seq',
#      ['Microarray analysis |'],
#      'Transcriptomics | transcriptomics,transcriptome profiling,transcriptomic profiling,transcriptome sequencing,transcriptomic analysis,transcriptome analysis',
#      ['RNA sequencing |  rna seq, rna analysis]',
#       'miRNA sequencing | mirna seq,mirna analysis]'],
#      'Whole genome sequencing | genome sequencing',
#      ['Exome sequencing |'],
#      'High-throughput methods | high throughput',
#      ['Long-read sequencing |', 'Short-read sequencing |'],
#      'Gene prediction | gene prediction,genetic prediction',
#      'Polygenic score | polygenic score,polygenic risk score,polygenic risk prediction',
#      'Genotype-to-phenotype prediction | phenotype prediction',
#      'Phenotype-to-genotype mapping | genotype mapping',
#      'DNA annotation | dna annotation, genome annotation'],
#     'Systems biology |',
#     'Consumer health |',
#     'Health care information systems |',
#     'Health informatics |',
#     'Bioinformatics |',
#     'Bioengineering |'],
#    'Metabolomics and metabonomics | metabolomics,metabonomic']]]
